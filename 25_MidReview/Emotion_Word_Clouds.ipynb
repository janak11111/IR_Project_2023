# %%
# read the dataset
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("preprocessed_emotion_dataset.csv")
df.head()
# Out:
#                                                tweet  \
# 0   #1: @fe ed "RT @MirayaDizon1: Time is ticking...
# 1   #3: @Ris ♡ ed "Happy birthday to one smokin h...
# 2   #4: @월월 [씍쯴사랑로봇] jwinnie is the best, cheer u...
# 3   #5: @Madhurima wth u vc♥ ed "Good morning dea...
# 4   #7: @Eric Rogers ed "@CaitlinUnruh The movie ...
#
#                                          clean_tweet emotion
# 0       time ticking fast relive past happy joy face   happy
# 1  happy birthday one hot love much amazing frien...   happy
# 2  best cheer left min cant save happy like treas...   happy
# 3  good morning wishing day filled sunshine happi...   happy
# 4  eric movie made happy several way think rely s...   happy

# %%
## extract emotion wise sample
happy_tweet = df[df.emotion == 'happy']
sad_tweet = df[df.emotion == 'sad']
angry_tweet = df[df.emotion == 'angry']
fear_tweet = df[df.emotion == 'fear']
disgust_tweet = df[df.emotion == 'disgust']
surprise_tweet = df[df.emotion == 'surprise']

# %%
## Word cloud image for emotion Happy
from PIL import Image
from wordcloud import WordCloud
text = " ".join(review for review in happy_tweet.clean_tweet)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="black").generate(text)
fig = plt.figure(figsize = (20, 6)) 
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
## Word cloud image for emotion Sad
text = " ".join(review for review in sad_tweet.clean_tweet)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="black").generate(text)
fig = plt.figure(figsize = (20, 6)) 
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
## Word cloud image for emotion Angry
text = " ".join(review for review in angry_tweet.clean_tweet)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="black").generate(text)
fig = plt.figure(figsize = (20, 6)) 
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
## Word cloud image for emotion Fear
text = " ".join(review for review in fear_tweet.clean_tweet)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="black").generate(text)
fig = plt.figure(figsize = (20, 6)) 
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
## Word cloud image for emotion Disgust
text = " ".join(review for review in disgust_tweet.clean_tweet)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="black").generate(text)
fig = plt.figure(figsize = (20, 6)) 
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
## Word cloud image for emotion surprise
text = " ".join(review for review in surprise_tweet.clean_tweet)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="black").generate(text)
fig = plt.figure(figsize = (20, 6)) 
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
